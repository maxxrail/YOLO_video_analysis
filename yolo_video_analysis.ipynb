# %% [markdown]
# ## Imports and Setup

# %%
# ============================================
# 0. Imports & Global Settings
# ============================================
import os
from pathlib import Path
from collections import defaultdict

import cv2
import numpy as np
import pandas as pd

from scipy.optimize import linear_sum_assignment

# YOLOv8
from ultralytics import YOLO
import torch

# DeepSORT
from deep_sort_realtime.deepsort_tracker import DeepSort

# Plotting / debug (optional)
import matplotlib.pyplot as plt

# %%
# ============================================
# 0.1 Paths & Constants
# ============================================
BASE_DIR = Path("Object_Tracking")

TASK1_IMAGES_DIR = BASE_DIR / "Task1" / "images"
TASK1_GT_PATH    = BASE_DIR / "Task1" / "gt" / "gt.txt"

TASK2_IMAGES_DIR = BASE_DIR / "Task2" / "images"

# Output paths
TASK1_INPUT_VIDEO  = Path("task1_input.mp4")
TASK1_OUTPUT_VIDEO = Path("task1.mp4")
TASK2_OUTPUT_VIDEO = Path("task2.mp4")
TASK2_COUNTS_CSV   = Path("task2_count.csv")

FPS_TASK1 = 14
FPS_TASK2 = 14

# YOLO weights
YOLO_WEIGHTS = "yolov8x.pt"  
YOLO_IMGSZ = 1920       # using full-res
YOLO_CONF = 0.25          # confidence threshold for task 1
# Pick CUDA if available, otherwise CPU
DEVICE = "cuda"

# %% [markdown]
# ## 1. Data Preparation (Task 1 – images → video @ 14 FPS)

# %%
# ============================================
# 1. Convert Task1 images to video (task1_input.mp4)
# ============================================
def images_to_video(image_dir: Path, output_path: Path, fps: int = 14):
    """
    Convert all images in image_dir to a video at the given fps.
    Assumes images are named so that lexicographic sort is correct frame order
    (e.g., 000001.jpg, 000002.jpg, ...).
    """
    image_files = sorted(
        [p for p in image_dir.iterdir() if p.suffix.lower() in [".jpg", ".jpeg", ".png"]]
    )
    assert len(image_files) > 0, f"No images found in {image_dir}"

    # Read first image to get frame size
    first_frame = cv2.imread(str(image_files[0]))
    assert first_frame is not None, f"Could not read first image {image_files[0]}"

    height, width = first_frame.shape[:2]
    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    out = cv2.VideoWriter(str(output_path), fourcc, fps, (width, height))

    for img_path in image_files:
        frame = cv2.imread(str(img_path))
        if frame is None:
            print(f"Warning: could not read {img_path}, skipping.")
            continue
        out.write(frame)

    out.release()
    print(f"Saved video: {output_path} ({len(image_files)} frames at {fps} FPS)")

# Run for Task1
images_to_video(TASK1_IMAGES_DIR, TASK1_INPUT_VIDEO, fps=FPS_TASK1)
# Out:
# Saved video: task1_input.mp4 (429 frames at 14 FPS)

# %% [markdown]
# ## 2. YOLOv8 + DeepSORT Tracking (Task 2 – Task1 video)

# %% [markdown]
# ### 2.1 Initialize YOLO and DeepSORT

# %% [markdown]
# We use YOLOv8 for pedestrian detection and DeepSORT to maintain consistent IDs across frames. Each frame is processed, detections are filtered to "person", and DeepSORT assigns a track ID. The output is both an annotated video and a MOT-format tracking file.

# %%
# ============================================
# 2.1 Initialize YOLOv8 and DeepSORT
# ============================================
def init_yolo(weights_path: str = YOLO_WEIGHTS, device: str = DEVICE):
    """
    Initialize YOLOv8 model on CPU or CUDA if available.
    """
    model = YOLO(weights_path)
    model.to(device)
    return model


def init_deepsort():
    """
    Initialize DeepSort tracker from deep_sort_realtime.
    """
    tracker = DeepSort(
        max_age=30,
        n_init=3,
        nn_budget=100,
        max_iou_distance=0.7,
        max_cosine_distance=0.2,
        embedder="mobilenet",
        half=False,
        bgr=True,
        embedder_gpu=True,
    )
    return tracker


yolo_model = init_yolo()
deepsort_tracker = init_deepsort()

# %% [markdown]
# ### Optional sharpening and brightening

# %% [markdown]
# Gamma correction and sharpening help improve contrast and edge clarity in frames. This makes small or low-contrast pedestrians slightly easier for the detector to recognize.

# %%
# Global hyperparameters for preprocessing
GAMMA = 1.3         # brightness gamma
SHARP_SIGMA = 0.9   # Gaussian blur sigma for unsharp mask
SHARP_AMOUNT = 1.8   # sharpening strength


def preprocess_frame(frame_bgr):
    """
    Preprocessing before detection/tracking:
      - apply gamma on V channel (brightness)
      - apply mild unsharp masking for sharpening
    Uses global GAMMA, SHARP_SIGMA, SHARP_AMOUNT.
    """

    # --- 1) Gamma on brightness (HSV V channel) ---
    hsv = cv2.cvtColor(frame_bgr, cv2.COLOR_BGR2HSV)
    h, s, v = cv2.split(hsv)

    v_float = v.astype(np.float32) / 255.0
    # gamma < 1 => brighter, gamma > 1 => darker
    v_gamma = np.power(v_float, GAMMA)
    v_new = np.clip(v_gamma * 255.0, 0, 255).astype(np.uint8)

    hsv = cv2.merge([h, s, v_new])
    img_bgr = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)

    # --- 2) Sharpening (unsharp mask) ---
    if SHARP_AMOUNT > 0:
        blurred = cv2.GaussianBlur(img_bgr, (0, 0), SHARP_SIGMA)
        sharp = cv2.addWeighted(
            img_bgr,
            1.0 + SHARP_AMOUNT,
            blurred,
            -SHARP_AMOUNT,
            0,
        )
        return sharp
    else:
        # no sharpening
        return img_bgr

# %% [markdown]
# ### 2.2 Helper: Run tracker on a video & save results

# %%
# ============================================
# 2.2 Run YOLOv8x + DeepSORT on Task1 video
#     with darken+sharpen preprocessing
# ============================================
def run_tracking(
    input_video_path: Path,
    output_video_path: Path,
    tracker_txt_out: Path,
    yolo_model,
    deepsort_tracker,
    fps: int,
    conf: float = YOLO_CONF,
    imgsz: int = YOLO_IMGSZ,
):
    """
    Run YOLOv8 + DeepSORT tracking on a video.

    Outputs:
      - Annotated video with tracking boxes & IDs
      - Text file with tracking results:
        <frame>, <id>, <bb_left>, <bb_top>, <bb_width>, <bb_height>
    Uses preprocess_frame() for detection (darken + sharpen).
    """
    cap = cv2.VideoCapture(str(input_video_path))
    assert cap.isOpened(), f"Cannot open {input_video_path}"

    # Get frame size from first frame
    ret, first_frame = cap.read()
    assert ret, "Could not read first frame"
    height, width = first_frame.shape[:2]
    cap.set(cv2.CAP_PROP_POS_FRAMES, 0)  # reset to start

    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    out = cv2.VideoWriter(str(output_video_path), fourcc, fps, (width, height))

    all_tracks = []  # (frame_idx, track_id, bb_left, bb_top, bb_width, bb_height)
    frame_idx = 0

    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frame_idx += 1

        # --- Preprocess for detector (darken + sharpen) ---
        frame_proc = preprocess_frame(frame)

        height, width = frame_proc.shape[:2]

        # YOLO inference on preprocessed frame
        results = yolo_model(frame_proc, imgsz=imgsz, conf=conf, verbose=False)[0]
        boxes = results.boxes

        detections = []
        if boxes is not None and len(boxes) > 0:
            xyxy  = boxes.xyxy.cpu().numpy()
            confs = boxes.conf.cpu().numpy()
            clss  = boxes.cls.cpu().numpy()

            for bbox, score, cls in zip(xyxy, confs, clss):
                # COCO class 0 = 'person'
                if int(cls) != 0:
                    continue
                x1, y1, x2, y2 = bbox

                # Clamp to image
                x1 = max(0.0, min(x1, width - 1.0))
                x2 = max(0.0, min(x2, width - 1.0))
                y1 = max(0.0, min(y1, height - 1.0))
                y2 = max(0.0, min(y2, height - 1.0))
                if x2 <= x1 or y2 <= y1:
                    continue

                # DeepSORT expects [x, y, w, h]
                w = x2 - x1
                h = y2 - y1

                detections.append(([x1, y1, w, h], float(score), "person"))

        # Update DeepSORT using preprocessed frame
        tracks = deepsort_tracker.update_tracks(detections, frame=frame_proc)

        for track in tracks:
            if not track.is_confirmed():
                continue

            # allow track to be drawn for up to 2 frames without an update
            if track.time_since_update > 0:
                continue

            track_id = track.track_id

            # Get left, top, right, bottom from tracker
            l, t, r, b = track.to_ltrb()
            l = max(0, min(int(l), width - 1))
            r = max(0, min(int(r), width - 1))
            t = max(0, min(int(t), height - 1))
            b = max(0, min(int(b), height - 1))

            bb_left   = float(l)
            bb_top    = float(t)
            bb_width  = float(r - l)
            bb_height = float(b - t)

            all_tracks.append(
                (frame_idx, int(track_id), bb_left, bb_top, bb_width, bb_height)
            )

            # Draw on preprocessed frame
            cv2.rectangle(frame_proc, (l, t), (r, b), (0, 255, 0), 2)
            cv2.putText(
                frame_proc,
                f"ID {track_id}",
                (l, t - 5),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.6,
                (0, 255, 0),
                2,
                cv2.LINE_AA,
            )

        out.write(frame_proc)

    cap.release()
    out.release()

    # Save tracking results to txt
    tracker_txt_out = Path(tracker_txt_out)
    with tracker_txt_out.open("w") as f:
        for (frame_idx, track_id, bb_left, bb_top, bb_width, bb_height) in all_tracks:
            f.write(
                f"{frame_idx},{track_id},{bb_left:.2f},{bb_top:.2f},"
                f"{bb_width:.2f},{bb_height:.2f}\n"
            )

    print(f"Tracking done. Saved video to {output_video_path}")
    print(f"Tracking results saved to {tracker_txt_out}")


# Run tracking for Task1
TASK1_TRACKS_TXT = Path("task1_tracks.txt")
run_tracking(
    TASK1_INPUT_VIDEO,
    TASK1_OUTPUT_VIDEO,
    TASK1_TRACKS_TXT,
    yolo_model,
    deepsort_tracker,
    fps=FPS_TASK1,
    conf=YOLO_CONF
)
# Out:
# Tracking done. Saved video to task1.mp4
# Tracking results saved to task1_tracks.txt

# %% [markdown]
# ## 3. Model Evaluation: MOTA (Task 3)

# %% [markdown]
# ### 3.1 Load ground truth

# %%
# ============================================
# 3.1 Load ground truth annotations (Task1/gt/gt.txt)
# Using only the first 6 columns:
# <frame>, <id>, <bb_left>, <bb_top>, <bb_width>, <bb_height>, ...
# ============================================
def load_gt(gt_path: Path):
    """
    Load ground truth from MOT-style gt.txt.

    Assumes columns:
      1: frame
      2: id
      3: bb_left
      4: bb_top
      5: bb_width
      6: bb_height
      [7: conf (optional)]
      [8: class (optional, 1 = pedestrian)]
      [9+: other fields, ignored]

    We:
      - skip lines with conf <= 0 (unlabeled / ignored)
      - if class column exists, keep only class == 1 (pedestrians)
    """
    gt_by_frame = defaultdict(list)

    with open(gt_path, "r") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue

            cols = line.split(",")
            if len(cols) < 6:
                continue

            frame = int(cols[0])
            obj_id = int(cols[1])
            bb_left   = float(cols[2])
            bb_top    = float(cols[3])
            bb_width  = float(cols[4])
            bb_height = float(cols[5])

            # Optional 7th column: conf
            if len(cols) >= 7:
                conf = float(cols[6])
                # MOT convention: conf <= 0 => ignore
                if conf <= 0:
                    continue

            # Optional 8th column: class (1 = pedestrian)
            if len(cols) >= 8:
                cls = int(cols[7])
                if cls != 1:
                    # keep only pedestrians
                    continue

            gt_by_frame[frame].append(
                {
                    "id": obj_id,
                    "bbox": [bb_left, bb_top, bb_width, bb_height],
                }
            )

    return gt_by_frame

gt_by_frame = load_gt(TASK1_GT_PATH)
print("Loaded GT frames:", len(gt_by_frame))
print("Total GT boxes:", sum(len(v) for v in gt_by_frame.values()))
# Out:
# Loaded GT frames: 429
# Total GT boxes: 19870

# %% [markdown]
# ### 3.2 Load predictions (tracker output)

# %%
# ============================================
# 3.2 Load tracking results from our tracker output txt
# Format: <frame>, <id>, <bb_left>, <bb_top>, <bb_width>, <bb_height>
# ============================================
def load_predictions(pred_path: Path):
    pred_by_frame = defaultdict(list)
    with pred_path.open("r") as f:
        for line in f:
            if not line.strip():
                continue
            parts = line.strip().split(",")
            frame = int(parts[0])
            track_id = int(parts[1])
            x = float(parts[2])
            y = float(parts[3])
            w = float(parts[4])
            h = float(parts[5])

            pred_by_frame[frame].append(
                {
                    "id": track_id,
                    "bbox": np.array([x, y, w, h], dtype=float),
                }
            )
    return pred_by_frame

pred_by_frame = load_predictions(TASK1_TRACKS_TXT)
print(f"Loaded predictions for {len(pred_by_frame)} frames")
# Out:
# Loaded predictions for 427 frames

# %% [markdown]
# ### 3.3 IoU, Hungarian matching

# %% [markdown]
# We compute IoU between GT and predicted boxes and use the Hungarian algorithm to match pairs with IoU ≥ 0.5. Unmatched predictions = FP; unmatched GT = FN; switching matched IDs across frames = IDSW.

# %%
# ============================================
# 3.3 IoU & matching utilities
# ============================================
def xywh_to_xyxy(box_xywh):
    """Convert [x, y, w, h] -> [x1, y1, x2, y2]."""
    x, y, w, h = box_xywh
    return np.array([x, y, x + w, y + h], dtype=float)


def compute_iou_matrix(gt_boxes_xywh, pred_boxes_xywh):
    """
    Compute IoU matrix between:
      - gt_boxes_xywh: list of [x, y, w, h]
      - pred_boxes_xywh: list of [x, y, w, h]
    Returns: (N_gt, N_pred) IoU matrix.
    """
    N = len(gt_boxes_xywh)
    M = len(pred_boxes_xywh)

    if N == 0 or M == 0:
        return np.zeros((N, M), dtype=float)

    gt = np.array([xywh_to_xyxy(b) for b in gt_boxes_xywh], dtype=float)  # (N,4)
    pr = np.array([xywh_to_xyxy(b) for b in pred_boxes_xywh], dtype=float)  # (M,4)

    gt_x1 = gt[:, 0][:, None]
    gt_y1 = gt[:, 1][:, None]
    gt_x2 = gt[:, 2][:, None]
    gt_y2 = gt[:, 3][:, None]

    pr_x1 = pr[:, 0][None, :]
    pr_y1 = pr[:, 1][None, :]
    pr_x2 = pr[:, 2][None, :]
    pr_y2 = pr[:, 3][None, :]

    inter_x1 = np.maximum(gt_x1, pr_x1)
    inter_y1 = np.maximum(gt_y1, pr_y1)
    inter_x2 = np.minimum(gt_x2, pr_x2)
    inter_y2 = np.minimum(gt_y2, pr_y2)

    inter_w = np.clip(inter_x2 - inter_x1, a_min=0, a_max=None)
    inter_h = np.clip(inter_y2 - inter_y1, a_min=0, a_max=None)
    inter_area = inter_w * inter_h

    gt_area = (gt_x2 - gt_x1) * (gt_y2 - gt_y1)   # (N,1)
    pr_area = (pr_x2 - pr_x1) * (pr_y2 - pr_y1)   # (1,M)
    union_area = gt_area + pr_area - inter_area

    iou = np.zeros_like(inter_area)
    mask = union_area > 0
    iou[mask] = inter_area[mask] / union_area[mask]
    return iou

# %% [markdown]
# ### 3.4 Compute MOTA, FP, FN, IDSW, GT

# %%
# ============================================
# 3.4 Compute MOTA, FP, FN, IDSW, GT
# ============================================
def compute_mota(gt_by_frame, pred_by_frame, iou_threshold=0.5):
    """
    Compute MOTA, and totals of FP, FN, IDSW, and GT.
    Following the definition given in the assignment.
    """
    frames = sorted(gt_by_frame.keys())       # frames with GT
    all_frames = frames                       # just use GT frames (fixed for issue)


    total_FP = 0
    total_FN = 0
    total_IDSW = 0
    total_GT = 0

    # For ID switch tracking: gt_id -> last matched pred_id
    prev_match_for_gt = {}

    for t in all_frames:
        gt_objs = gt_by_frame.get(t, [])
        pr_objs = pred_by_frame.get(t, [])

        gt_boxes = [g["bbox"] for g in gt_objs]
        gt_ids = [g["id"] for g in gt_objs]

        pr_boxes = [p["bbox"] for p in pr_objs]
        pr_ids = [p["id"] for p in pr_objs]

        N = len(gt_boxes)
        M = len(pr_boxes)

        total_GT += N

        if N == 0 and M == 0:
            # nothing here
            continue

        # IoU matrix
        iou_mat = compute_iou_matrix(gt_boxes, pr_boxes)

        if N > 0 and M > 0:
            # Cost matrix for Hungarian: we want to maximize IoU,
            # so we minimize (1 - IoU). Set cost very high if IoU < threshold.
            cost = 1.0 - iou_mat
            cost[iou_mat < iou_threshold] = 1e6

            row_ind, col_ind = linear_sum_assignment(cost)

            matched_gt_idx = set()
            matched_pr_idx = set()

            # Evaluate matches above threshold
            for r, c in zip(row_ind, col_ind):
                if iou_mat[r, c] >= iou_threshold:
                    matched_gt_idx.add(r)
                    matched_pr_idx.add(c)

                    gt_id = gt_ids[r]
                    pr_id = pr_ids[c]

                    # Identity switch
                    if gt_id in prev_match_for_gt:
                        if prev_match_for_gt[gt_id] != pr_id:
                            total_IDSW += 1
                    prev_match_for_gt[gt_id] = pr_id

            # FN: GT with no match
            FN_t = N - len(matched_gt_idx)

            # FP: predictions with no match
            FP_t = M - len(matched_pr_idx)

        elif N == 0 and M > 0:
            # All predictions are FP
            FP_t = M
            FN_t = 0

        elif N > 0 and M == 0:
            # All GT are FN
            FN_t = N
            FP_t = 0

        total_FN += FN_t
        total_FP += FP_t

    if total_GT == 0:
        mota = 0.0
    else:
        mota = 1.0 - (total_FN + total_FP + total_IDSW) / total_GT

    return mota, total_FP, total_FN, total_IDSW, total_GT


mota, total_FP, total_FN, total_IDSW, total_GT = compute_mota(
    gt_by_frame, pred_by_frame, iou_threshold=0.5
)

print(f"MOTA: {mota:.4f}")
print(f"Total GT:   {total_GT}")
print(f"Total FP:   {total_FP}")
print(f"Total FN:   {total_FN}")
print(f"Total IDSW: {total_IDSW}")
# Out:
# MOTA: 0.4686
# Total GT:   19870
# Total FP:   2464
# Total FN:   7594
# Total IDSW: 500

# %%
# debug: how many GT vs predictions per frame?
all_gt_frames = sorted(gt_by_frame.keys())
all_pred_frames = sorted(pred_by_frame.keys())

total_GT = sum(len(gt_by_frame[f]) for f in all_gt_frames)
total_pred = sum(len(pred_by_frame.get(f, [])) for f in all_gt_frames)

print("Frames with GT:", len(all_gt_frames))
print("Total GT boxes:", total_GT, "-> avg per frame:", total_GT / len(all_gt_frames))
print("Total pred boxes on those frames:", total_pred, "-> avg per frame:", total_pred / len(all_gt_frames))
# Out:
# Frames with GT: 429
# Total GT boxes: 19870 -> avg per frame: 46.31701631701632
# Total pred boxes on those frames: 14740 -> avg per frame: 34.35897435897436

# %% [markdown]
# ## MOTA Score Explanation
#
# Our tracker achieved **MOTA = 0.47**. This is mainly due to:
#
# - **High FN (missed people):** Many pedestrians are far away, small, or occluded, so YOLOv8 fails to detect them.
# - **High FP (extra detections):** Background textures and shadows sometimes trigger false positives.
# - **Identity switches:** Pedestrians overlap and look very similar, causing DeepSORT to change IDs when tracks are lost or occluded.
# - **Low FPS (14):** Larger motion between frames makes tracking harder and increases ID switches.
#
# All these errors contribute directly to lowering the MOTA score.

# %% [markdown]
# ### DEBUG sweep sharpening brightness and confidence values

# %%
from pathlib import Path
import itertools
import pandas as pd

# ============================================
# Hyperparameter sweep: conf × gamma × sigma × amount
# ============================================

# Confidence values to try
CONF_SWEEP = [0.29, 0.28, 0.27, 0.26, 0.25]

# Preprocessing hyperparam grids 
GAMMA_SWEEP = [1.3]   
SIGMA_SWEEP = [0.9]        
AMOUNT_SWEEP = [1.8, 1.9]      

sweep_results = []

# Load GT once
gt_by_frame = load_gt(TASK1_GT_PATH)

for conf in CONF_SWEEP:
    print("\n" + "=" * 70)
    print(f"### Sweeping hyperparams for conf = {conf:.2f}")
    print("=" * 70)

    # For this conf, reuse same output filenames
    tag = int(conf * 100)
    task1_video_out  = Path(f"task1_conf{tag:03d}.mp4")
    task1_tracks_out = Path(f"task1_tracks_conf{tag:03d}.txt")

    for gamma, sigma, amount in itertools.product(GAMMA_SWEEP, SIGMA_SWEEP, AMOUNT_SWEEP):
        # Set global preprocess hyperparameters
        GAMMA = gamma
        SHARP_SIGMA = sigma
        SHARP_AMOUNT = amount

        print(
            f"\n--- conf={conf:.2f}, gamma={gamma:.2f}, "
            f"sigma={sigma:.2f}, amount={amount:.2f} ---"
        )

        # Fresh model + tracker for each combo
        yolo_model_t1 = init_yolo()
        deepsort_t1   = init_deepsort()

        # Run tracking with these hyperparams
        run_tracking(
            TASK1_INPUT_VIDEO,
            task1_video_out,
            task1_tracks_out,
            yolo_model_t1,
            deepsort_t1,
            fps=FPS_TASK1,
            conf=conf,
            imgsz=YOLO_IMGSZ,
        )

        # Compute MOTA for this combo
        pred_by_frame = load_predictions(task1_tracks_out)

        mota, total_FP, total_FN, total_IDSW, total_GT = compute_mota(
            gt_by_frame, pred_by_frame, iou_threshold=0.5
        )

        print(
            f"MOTA={mota:.4f} | FP={total_FP} | FN={total_FN} | "
            f"IDSW={total_IDSW} | GT={total_GT}"
        )

        sweep_results.append(
            {
                "conf": conf,
                "gamma": gamma,
                "sigma": sigma,
                "amount": amount,
                "MOTA": mota,
                "FP": total_FP,
                "FN": total_FN,
                "IDSW": total_IDSW,
                "GT": total_GT,
            }
        )

# Turn results into a DataFrame 
sweep_df = pd.DataFrame(sweep_results)
sweep_df

# %% [markdown]
# ## 4. Prediction & Kaggle Competition

# %% [markdown]
# ### 4.1 Convert Task2 images to a video and track

# %% [markdown]
# ## Task 2 Counting Method
#
# For each frame, we use Faster R-CNN to detect pedestrians and count all detection boxes above a chosen confidence threshold. These per-frame counts are saved in a CSV file for Kaggle evaluation.
#
# Although we implemented DeepSORT for Task 2 as well, we found during testing that **using only the detector (no tracker) and tuning the confidence threshold produced a better Kaggle score**. The tracker's identity persistence is not needed for counting and sometimes increases false positives.
#
# However, **the assignment requires an annotated tracking video**, so our submitted `task2.mp4` uses the tracker, while the Kaggle CSV uses the detector-only counts.
#
# ## Reason for Using Faster R-CNN
#
# We chose Faster R-CNN because it performs more reliably on medium-sized pedestrians and produces more stable scores across frames compared to YOLOv8. This stability makes confidence-based counting more consistent, especially when not using a tracker for the Kaggle submission.

# %%
# ============================================
# 4.1 Task2: Faster R-CNN + DeepSORT on Task2 images
#     - Preprocess frames
#     - Build input video (task2_input.mp4)
#     - Build tracked video (task2.mp4)
#     - Save tracking results (task2_tracks.txt)
#     - Return per-frame counts for CSV
# ============================================
import torch
from pathlib import Path
from PIL import Image
from torchvision.transforms import functional as F
from torchvision.models.detection import fasterrcnn_resnet50_fpn_v2

# cv2, np, DeepSort imported earlier in the notebook.

# Task2-specific settings 
DEVICE_T2       = "cuda"   
FPS_TASK2       = 14.0     
SCORE_THRESH_T2 = 0.475    # detector score threshold

# Paths for Task2
TASK2_INPUT_VIDEO  = Path("task2_input.mp4")
TASK2_TRACKS_TXT   = Path("task2_tracks.txt")


def load_frcnn_detector(device: str = DEVICE_T2):
    """
    Load a Faster R-CNN ResNet50 FPN v2 detector with COCO weights.
    """
    if device == "cuda" and not torch.cuda.is_available():
        print("CUDA requested but not available, falling back to CPU.")
        device = "cpu"

    model = fasterrcnn_resnet50_fpn_v2(weights="DEFAULT")
    model.to(device)
    model.eval()
    return model, device


def init_deepsort_task2():
    """
    Initialize DeepSort tracker for Task2.
    """
    tracker = DeepSort(
        max_age=30,
        n_init=3,
        max_iou_distance=0.7,
        nms_max_overlap=1.0,
        max_cosine_distance=0.2,
        embedder="mobilenet",
        half=False,
        bgr=True,
        embedder_gpu=True,
    )
    return tracker


def preprocess_frame(frame_bgr):
    """
    Darken bright regions and sharpen the image to help detector.
    """
    # 1) Darken highlights using gamma on V channel in HSV
    hsv = cv2.cvtColor(frame_bgr, cv2.COLOR_BGR2HSV)
    h, s, v = cv2.split(hsv)

    v_float = v.astype(np.float32) / 255.0
    gamma = 1.4
    v_gamma = np.power(v_float, gamma)
    v_new = np.clip(v_gamma * 255.0, 0, 255).astype(np.uint8)

    hsv = cv2.merge([h, s, v_new])
    img_bgr = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)

    # 2) Stronger sharpening (unsharp mask)
    sigma = 1.2
    amount = 1.8
    blurred = cv2.GaussianBlur(img_bgr, (0, 0), sigma)
    sharp = cv2.addWeighted(img_bgr, 1.0 + amount, blurred, -amount, 0)

    return sharp


def process_task2_frames(
    frames_dir: Path,
    input_video_path: Path,
    tracked_video_path: Path,
    tracks_txt_path: Path,
    fps: float = FPS_TASK2,
    device: str = DEVICE_T2,
    score_thresh: float = SCORE_THRESH_T2,
):
    """
    - Reads Task2 frames from frames_dir
    - Builds a raw input video (input_video_path)
    - Runs Faster R-CNN + DeepSORT on preprocessed frames
    - Builds a tracked video (tracked_video_path)
    - Saves MOT-style tracks to tracks_txt_path
    - Returns: dict[frame_idx] -> person_count (from detector boxes)
    """
    # Load detector + tracker
    model, device = load_frcnn_detector(device)
    tracker = init_deepsort_task2()

    image_paths = sorted(frames_dir.glob("*.jpg"))
    if not image_paths:
        raise FileNotFoundError(f"No .jpg files found in {frames_dir}")

    # Read first frame to get size
    first_frame = cv2.imread(str(image_paths[0]))
    if first_frame is None:
        raise RuntimeError(f"Could not read first frame: {image_paths[0]}")

    height, width = first_frame.shape[:2]
    fourcc = cv2.VideoWriter_fourcc(*"mp4v")

    # Video writers
    input_writer = cv2.VideoWriter(str(input_video_path), fourcc, fps, (width, height))
    tracked_writer = cv2.VideoWriter(str(tracked_video_path), fourcc, fps, (width, height))

    # Outputs
    track_lines = []      # for MOT-style txt
    frame_counts = {}     # frame_idx -> person_count

    frame_idx = 0

    with torch.no_grad():
        for img_path in image_paths:
            frame_idx += 1

            frame_bgr = cv2.imread(str(img_path))
            if frame_bgr is None:
                print(f"WARNING: could not read {img_path}, skipping.")
                continue

            original_bgr = frame_bgr.copy()

            # Preprocess for detector (Optional)
            # frame_bgr = preprocess_frame(frame_bgr)

            # Write original raw frame to input video
            input_writer.write(original_bgr)

            # Prepare image for detector (RGB) using preprocessed frame
            rgb = cv2.cvtColor(frame_bgr, cv2.COLOR_BGR2RGB)
            pil_img = Image.fromarray(rgb)
            tensor = F.to_tensor(pil_img).to(device)

            outputs = model([tensor])[0]
            boxes = outputs["boxes"].cpu()
            labels = outputs["labels"].cpu()
            scores = outputs["scores"].cpu()

            detections = []
            person_count = 0

            # Build detections for DeepSort
            for box, label, score in zip(boxes, labels, scores):
                if label.item() != 1:  # COCO: 1 = person
                    continue
                if score.item() < score_thresh:
                    continue

                x1, y1, x2, y2 = box.tolist()

                # Clamp to frame
                x1 = max(0.0, min(x1, width - 1.0))
                x2 = max(0.0, min(x2, width - 1.0))
                y1 = max(0.0, min(y1, height - 1.0))
                y2 = max(0.0, min(y2, height - 1.0))

                if x2 <= x1 or y2 <= y1:
                    continue

                w = x2 - x1
                h = y2 - y1

                detections.append(([x1, y1, w, h], float(score.item()), "person"))
                person_count += 1

            # Update tracker
            tracks = tracker.update_tracks(detections, frame=frame_bgr)

            # Draw tracks and build MOT lines
            for trk in tracks:
                if not trk.is_confirmed() or trk.time_since_update > 0:
                    continue

                x1, y1, x2, y2 = map(int, trk.to_ltrb())

                # Clamp
                x1 = max(0, min(x1, width - 1))
                x2 = max(0, min(x2, width - 1))
                y1 = max(0, min(y1, height - 1))
                y2 = max(0, min(y2, height - 1))

                bb_left = x1
                bb_top = y1
                bb_width = max(0, x2 - x1)
                bb_height = max(0, y2 - y1)
                track_id = trk.track_id

                # Draw rectangle + ID
                cv2.rectangle(
                    frame_bgr,
                    (bb_left, bb_top),
                    (bb_left + bb_width, bb_top + bb_height),
                    (0, 255, 0),
                    2,
                )
                cv2.putText(
                    frame_bgr,
                    f"ID {track_id}",
                    (bb_left, max(0, bb_top - 5)),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    0.5,
                    (0, 255, 0),
                    1,
                    cv2.LINE_AA,
                )

                # MOT-style line: <frame>, <id>, <bb_left>, <bb_top>, <bb_width>, <bb_height>
                track_lines.append(
                    f"{frame_idx}, {track_id}, {bb_left}, {bb_top}, {bb_width}, {bb_height}\n"
                )

            # Write tracked frame (preprocessed + annotations)
            tracked_writer.write(frame_bgr)

            # Save count for this frame (detector-based, not unique IDs)
            frame_counts[frame_idx] = person_count

            print(
                f"Frame {frame_idx:4d}: {person_count:2d} people,"
                f" {len(detections)} detections, {len(tracks)} tracks"
            )

    # Release videos
    input_writer.release()
    tracked_writer.release()

    # Write tracks txt
    tracks_txt_path.parent.mkdir(parents=True, exist_ok=True)
    with tracks_txt_path.open("w") as f:
        f.writelines(track_lines)

    print(f"\nSaved input video to   {input_video_path}")
    print(f"Saved tracked video to {tracked_video_path}")
    print(f"Saved tracks to        {tracks_txt_path}")

    return frame_counts


# ---- Run Task2 processing and get per-frame counts ----
task2_frame_counts = process_task2_frames(
    frames_dir=TASK2_IMAGES_DIR,
    input_video_path=TASK2_INPUT_VIDEO,
    tracked_video_path=TASK2_OUTPUT_VIDEO,
    tracks_txt_path=TASK2_TRACKS_TXT,
    fps=FPS_TASK2,
    device=DEVICE_T2,
    score_thresh=SCORE_THRESH_T2,
)
# Out:
# Frame    1: 46 people, 46 detections, 46 tracks
# Frame    2: 46 people, 46 detections, 46 tracks
# Frame    3: 47 people, 47 detections, 47 tracks
# Frame    4: 48 people, 48 detections, 48 tracks
# Frame    5: 48 people, 48 detections, 48 tracks
# Frame    6: 47 people, 47 detections, 48 tracks
# Frame    7: 48 people, 48 detections, 50 tracks
# Frame    8: 46 people, 46 detections, 48 tracks
# Frame    9: 49 people, 49 detections, 50 tracks
# Frame   10: 44 people, 44 detections, 49 tracks
# Frame   11: 43 people, 43 detections, 47 tracks
# Frame   12: 42 people, 42 detections, 47 tracks
# Frame   13: 46 people, 46 detections, 50 tracks
# Frame   14: 44 people, 44 detections, 50 tracks
# Frame   15: 42 people, 42 detections, 48 tracks
# Frame   16: 42 people, 42 detections, 48 tracks
# Frame   17: 43 people, 43 detections, 48 tracks
# Frame   18: 45 people, 45 detections, 50 tracks
# Frame   19: 41 people, 41 detections, 49 tracks
# Frame   20: 41 people, 41 detections, 49 tracks
# Frame   21: 43 people, 43 detections, 51 tracks
# Frame   22: 42 people, 42 detections, 48 tracks
# Frame   23: 38 people, 38 detections, 48 tracks
# Frame   24: 41 people, 41 detections, 50 tracks
# Frame   25: 40 people, 40 detections, 50 tracks
# Frame   26: 39 people, 39 detections, 49 tracks
# Frame   27: 42 people, 42 detections, 51 tracks
# Frame   28: 42 people, 42 detections, 51 tracks
# Frame   29: 42 people, 42 detections, 51 tracks
# Frame   30: 41 people, 41 detections, 51 tracks
# Frame   31: 44 people, 44 detections, 53 tracks
# Frame   32: 42 people, 42 detections, 52 tracks
# Frame   33: 41 people, 41 detections, 53 tracks
# Frame   34: 43 people, 43 detections, 53 tracks
# Frame   35: 42 people, 42 detections, 54 tracks
# Frame   36: 41 people, 41 detections, 55 tracks
# Frame   37: 40 people, 40 detections, 53 tracks
# Frame   38: 41 people, 41 detections, 53 tracks
# Frame   39: 42 people, 42 detections, 53 tracks
# Frame   40: 40 people, 40 detections, 52 tracks
# Frame   41: 38 people, 38 detections, 52 tracks
# Frame   42: 40 people, 40 detections, 53 tracks
# Frame   43: 38 people, 38 detections, 53 tracks
# Frame   44: 41 people, 41 detections, 54 tracks
# Frame   45: 42 people, 42 detections, 55 tracks
# Frame   46: 40 people, 40 detections, 55 tracks
# Frame   47: 37 people, 37 detections, 55 tracks
# Frame   48: 42 people, 42 detections, 57 tracks
# Frame   49: 38 people, 38 detections, 55 tracks
# Frame   50: 41 people, 41 detections, 55 tracks
# Frame   51: 39 people, 39 detections, 56 tracks
# Frame   52: 40 people, 40 detections, 56 tracks
# Frame   53: 40 people, 40 detections, 55 tracks
# Frame   54: 40 people, 40 detections, 55 tracks
# Frame   55: 39 people, 39 detections, 55 tracks
# Frame   56: 36 people, 36 detections, 54 tracks
# Frame   57: 38 people, 38 detections, 55 tracks
# Frame   58: 39 people, 39 detections, 55 tracks
# Frame   59: 38 people, 38 detections, 55 tracks
# Frame   60: 40 people, 40 detections, 55 tracks
# Frame   61: 39 people, 39 detections, 56 tracks
# Frame   62: 41 people, 41 detections, 57 tracks
# Frame   63: 38 people, 38 detections, 56 tracks
# Frame   64: 41 people, 41 detections, 57 tracks
# Frame   65: 42 people, 42 detections, 58 tracks
# Frame   66: 39 people, 39 detections, 56 tracks
# Frame   67: 40 people, 40 detections, 57 tracks
# Frame   68: 40 people, 40 detections, 56 tracks
# Frame   69: 39 people, 39 detections, 56 tracks
# Frame   70: 41 people, 41 detections, 55 tracks
# Frame   71: 39 people, 39 detections, 54 tracks
# Frame   72: 41 people, 41 detections, 56 tracks
# Frame   73: 42 people, 42 detections, 56 tracks
# Frame   74: 43 people, 43 detections, 57 tracks
# Frame   75: 41 people, 41 detections, 57 tracks
# Frame   76: 40 people, 40 detections, 56 tracks
# Frame   77: 42 people, 42 detections, 58 tracks
# Frame   78: 42 people, 42 detections, 58 tracks
# Frame   79: 41 people, 41 detections, 56 tracks
# Frame   80: 40 people, 40 detections, 56 tracks
# Frame   81: 39 people, 39 detections, 53 tracks
# Frame   82: 38 people, 38 detections, 54 tracks
# Frame   83: 41 people, 41 detections, 55 tracks
# Frame   84: 42 people, 42 detections, 56 tracks
# Frame   85: 41 people, 41 detections, 55 tracks
# Frame   86: 41 people, 41 detections, 54 tracks
# Frame   87: 41 people, 41 detections, 54 tracks
# Frame   88: 40 people, 40 detections, 55 tracks
# Frame   89: 41 people, 41 detections, 54 tracks
# Frame   90: 39 people, 39 detections, 53 tracks
# Frame   91: 41 people, 41 detections, 53 tracks
# Frame   92: 39 people, 39 detections, 52 tracks
# Frame   93: 40 people, 40 detections, 53 tracks
# Frame   94: 40 people, 40 detections, 53 tracks
# Frame   95: 40 people, 40 detections, 53 tracks
# Frame   96: 40 people, 40 detections, 55 tracks
# Frame   97: 40 people, 40 detections, 52 tracks
# Frame   98: 43 people, 43 detections, 54 tracks
# Frame   99: 42 people, 42 detections, 54 tracks
# Frame  100: 39 people, 39 detections, 52 tracks
# Frame  101: 38 people, 38 detections, 52 tracks
# Frame  102: 39 people, 39 detections, 53 tracks
# Frame  103: 39 people, 39 detections, 52 tracks
# Frame  104: 39 people, 39 detections, 52 tracks
# Frame  105: 40 people, 40 detections, 53 tracks
# Frame  106: 40 people, 40 detections, 53 tracks
# Frame  107: 41 people, 41 detections, 51 tracks
# Frame  108: 39 people, 39 detections, 50 tracks
# Frame  109: 39 people, 39 detections, 50 tracks
# Frame  110: 40 people, 40 detections, 52 tracks
# Frame  111: 39 people, 39 detections, 50 tracks
# Frame  112: 40 people, 40 detections, 50 tracks
# Frame  113: 40 people, 40 detections, 49 tracks
# Frame  114: 39 people, 39 detections, 49 tracks
# Frame  115: 40 people, 40 detections, 49 tracks
# Frame  116: 42 people, 42 detections, 49 tracks
# Frame  117: 40 people, 40 detections, 48 tracks
# Frame  118: 40 people, 40 detections, 49 tracks
# Frame  119: 42 people, 42 detections, 48 tracks
# Frame  120: 41 people, 41 detections, 48 tracks
# Frame  121: 39 people, 39 detections, 47 tracks
# Frame  122: 41 people, 41 detections, 48 tracks
# Frame  123: 41 people, 41 detections, 47 tracks
# Frame  124: 42 people, 42 detections, 49 tracks
# Frame  125: 40 people, 40 detections, 48 tracks
# Frame  126: 41 people, 41 detections, 50 tracks
# Frame  127: 40 people, 40 detections, 50 tracks
# Frame  128: 41 people, 41 detections, 50 tracks
# Frame  129: 43 people, 43 detections, 51 tracks
# Frame  130: 40 people, 40 detections, 50 tracks
# Frame  131: 43 people, 43 detections, 50 tracks
# Frame  132: 43 people, 43 detections, 52 tracks
# Frame  133: 44 people, 44 detections, 51 tracks
# Frame  134: 41 people, 41 detections, 51 tracks
# Frame  135: 41 people, 41 detections, 51 tracks
# Frame  136: 40 people, 40 detections, 51 tracks
# Frame  137: 39 people, 39 detections, 50 tracks
# Frame  138: 43 people, 43 detections, 51 tracks
# Frame  139: 41 people, 41 detections, 51 tracks
# Frame  140: 38 people, 38 detections, 51 tracks
# Frame  141: 40 people, 40 detections, 50 tracks
# Frame  142: 40 people, 40 detections, 50 tracks
# Frame  143: 41 people, 41 detections, 51 tracks
# Frame  144: 42 people, 42 detections, 52 tracks
# Frame  145: 41 people, 41 detections, 51 tracks
# Frame  146: 41 people, 41 detections, 53 tracks
# Frame  147: 43 people, 43 detections, 52 tracks
# Frame  148: 44 people, 44 detections, 52 tracks
# Frame  149: 45 people, 45 detections, 52 tracks
# Frame  150: 43 people, 43 detections, 52 tracks
# Frame  151: 41 people, 41 detections, 51 tracks
# Frame  152: 41 people, 41 detections, 51 tracks
# Frame  153: 41 people, 41 detections, 51 tracks
# Frame  154: 43 people, 43 detections, 52 tracks
# Frame  155: 43 people, 43 detections, 53 tracks
# Frame  156: 44 people, 44 detections, 52 tracks
# Frame  157: 48 people, 48 detections, 52 tracks
# Frame  158: 42 people, 42 detections, 52 tracks
# Frame  159: 42 people, 42 detections, 51 tracks
# Frame  160: 42 people, 42 detections, 51 tracks
# Frame  161: 43 people, 43 detections, 52 tracks
# Frame  162: 48 people, 48 detections, 54 tracks
# Frame  163: 41 people, 41 detections, 52 tracks
# Frame  164: 41 people, 41 detections, 51 tracks
# Frame  165: 41 people, 41 detections, 51 tracks
# Frame  166: 45 people, 45 detections, 52 tracks
# Frame  167: 43 people, 43 detections, 52 tracks
# Frame  168: 44 people, 44 detections, 52 tracks
# Frame  169: 42 people, 42 detections, 52 tracks
# Frame  170: 42 people, 42 detections, 52 tracks
# Frame  171: 43 people, 43 detections, 52 tracks
# Frame  172: 44 people, 44 detections, 52 tracks
# Frame  173: 43 people, 43 detections, 52 tracks
# Frame  174: 42 people, 42 detections, 52 tracks
# Frame  175: 44 people, 44 detections, 52 tracks
# Frame  176: 43 people, 43 detections, 53 tracks
# Frame  177: 44 people, 44 detections, 52 tracks
# Frame  178: 43 people, 43 detections, 52 tracks
# Frame  179: 44 people, 44 detections, 52 tracks
# Frame  180: 43 people, 43 detections, 53 tracks
# Frame  181: 43 people, 43 detections, 52 tracks
# Frame  182: 42 people, 42 detections, 52 tracks
# Frame  183: 43 people, 43 detections, 52 tracks
# Frame  184: 43 people, 43 detections, 52 tracks
# Frame  185: 44 people, 44 detections, 53 tracks
# Frame  186: 45 people, 45 detections, 53 tracks
# Frame  187: 46 people, 46 detections, 52 tracks
# Frame  188: 44 people, 44 detections, 50 tracks
# Frame  189: 45 people, 45 detections, 51 tracks
# Frame  190: 44 people, 44 detections, 51 tracks
# Frame  191: 43 people, 43 detections, 50 tracks
# Frame  192: 43 people, 43 detections, 50 tracks
# Frame  193: 46 people, 46 detections, 50 tracks
# Frame  194: 44 people, 44 detections, 49 tracks
# Frame  195: 44 people, 44 detections, 49 tracks
# Frame  196: 46 people, 46 detections, 51 tracks
# Frame  197: 44 people, 44 detections, 50 tracks
# Frame  198: 44 people, 44 detections, 50 tracks
# Frame  199: 43 people, 43 detections, 50 tracks
# Frame  200: 46 people, 46 detections, 51 tracks
# Frame  201: 46 people, 46 detections, 51 tracks
# Frame  202: 48 people, 48 detections, 52 tracks
# Frame  203: 47 people, 47 detections, 51 tracks
# Frame  204: 47 people, 47 detections, 53 tracks
# Frame  205: 45 people, 45 detections, 51 tracks
# Frame  206: 45 people, 45 detections, 52 tracks
# Frame  207: 46 people, 46 detections, 54 tracks
# Frame  208: 44 people, 44 detections, 52 tracks
# Frame  209: 46 people, 46 detections, 51 tracks
# Frame  210: 44 people, 44 detections, 51 tracks
# Frame  211: 46 people, 46 detections, 52 tracks
# Frame  212: 45 people, 45 detections, 52 tracks
# Frame  213: 47 people, 47 detections, 52 tracks
# Frame  214: 46 people, 46 detections, 53 tracks
# Frame  215: 46 people, 46 detections, 52 tracks
# Frame  216: 46 people, 46 detections, 52 tracks
# Frame  217: 46 people, 46 detections, 52 tracks
# Frame  218: 49 people, 49 detections, 53 tracks
# Frame  219: 44 people, 44 detections, 52 tracks
# Frame  220: 47 people, 47 detections, 52 tracks
# Frame  221: 47 people, 47 detections, 52 tracks
# Frame  222: 48 people, 48 detections, 53 tracks
# Frame  223: 48 people, 48 detections, 53 tracks
# Frame  224: 47 people, 47 detections, 52 tracks
# Frame  225: 46 people, 46 detections, 53 tracks
# Frame  226: 43 people, 43 detections, 53 tracks
# Frame  227: 42 people, 42 detections, 52 tracks
# Frame  228: 43 people, 43 detections, 52 tracks
# Frame  229: 41 people, 41 detections, 52 tracks
# Frame  230: 44 people, 44 detections, 54 tracks
# Frame  231: 44 people, 44 detections, 53 tracks
# Frame  232: 44 people, 44 detections, 53 tracks
# Frame  233: 45 people, 45 detections, 53 tracks
# Frame  234: 47 people, 47 detections, 52 tracks
# Frame  235: 44 people, 44 detections, 52 tracks
# Frame  236: 41 people, 41 detections, 52 tracks
# Frame  237: 43 people, 43 detections, 52 tracks
# Frame  238: 41 people, 41 detections, 53 tracks
# Frame  239: 44 people, 44 detections, 53 tracks
# Frame  240: 42 people, 42 detections, 53 tracks
# Frame  241: 44 people, 44 detections, 54 tracks
# Frame  242: 44 people, 44 detections, 53 tracks
# Frame  243: 45 people, 45 detections, 53 tracks
# Frame  244: 45 people, 45 detections, 53 tracks
# Frame  245: 43 people, 43 detections, 53 tracks
# Frame  246: 46 people, 46 detections, 54 tracks
# Frame  247: 46 people, 46 detections, 53 tracks
# Frame  248: 46 people, 46 detections, 52 tracks
# Frame  249: 47 people, 47 detections, 54 tracks
# Frame  250: 46 people, 46 detections, 53 tracks
# Frame  251: 44 people, 44 detections, 53 tracks
# Frame  252: 45 people, 45 detections, 54 tracks
# Frame  253: 45 people, 45 detections, 55 tracks
# Frame  254: 43 people, 43 detections, 54 tracks
# Frame  255: 44 people, 44 detections, 54 tracks
# Frame  256: 44 people, 44 detections, 55 tracks
# Frame  257: 46 people, 46 detections, 56 tracks
# Frame  258: 48 people, 48 detections, 57 tracks
# Frame  259: 46 people, 46 detections, 55 tracks
# Frame  260: 44 people, 44 detections, 55 tracks
# Frame  261: 49 people, 49 detections, 58 tracks
# Frame  262: 46 people, 46 detections, 57 tracks
# Frame  263: 47 people, 47 detections, 58 tracks
# Frame  264: 48 people, 48 detections, 58 tracks
# Frame  265: 50 people, 50 detections, 59 tracks
# Frame  266: 52 people, 52 detections, 60 tracks
# Frame  267: 47 people, 47 detections, 58 tracks
# Frame  268: 48 people, 48 detections, 59 tracks
# Frame  269: 48 people, 48 detections, 59 tracks
# Frame  270: 49 people, 49 detections, 59 tracks
# Frame  271: 47 people, 47 detections, 58 tracks
# Frame  272: 48 people, 48 detections, 59 tracks
# Frame  273: 48 people, 48 detections, 60 tracks
# Frame  274: 47 people, 47 detections, 60 tracks
# Frame  275: 48 people, 48 detections, 62 tracks
# Frame  276: 50 people, 50 detections, 61 tracks
# Frame  277: 47 people, 47 detections, 61 tracks
# Frame  278: 48 people, 48 detections, 61 tracks
# Frame  279: 51 people, 51 detections, 63 tracks
# Frame  280: 50 people, 50 detections, 59 tracks
# Frame  281: 48 people, 48 detections, 61 tracks
# Frame  282: 48 people, 48 detections, 59 tracks
# Frame  283: 44 people, 44 detections, 59 tracks
# Frame  284: 47 people, 47 detections, 60 tracks
# Frame  285: 43 people, 43 detections, 59 tracks
# Frame  286: 46 people, 46 detections, 61 tracks
# Frame  287: 43 people, 43 detections, 59 tracks
# Frame  288: 43 people, 43 detections, 60 tracks
# Frame  289: 44 people, 44 detections, 58 tracks
# Frame  290: 45 people, 45 detections, 58 tracks
# Frame  291: 44 people, 44 detections, 57 tracks
# Frame  292: 43 people, 43 detections, 57 tracks
# Frame  293: 45 people, 45 detections, 58 tracks
# Frame  294: 43 people, 43 detections, 57 tracks
# Frame  295: 48 people, 48 detections, 60 tracks
# Frame  296: 47 people, 47 detections, 60 tracks
# Frame  297: 46 people, 46 detections, 59 tracks
# Frame  298: 45 people, 45 detections, 59 tracks
# Frame  299: 46 people, 46 detections, 60 tracks
# Frame  300: 47 people, 47 detections, 62 tracks
# Frame  301: 49 people, 49 detections, 63 tracks
# Frame  302: 45 people, 45 detections, 61 tracks
# Frame  303: 49 people, 49 detections, 64 tracks
# Frame  304: 49 people, 49 detections, 63 tracks
# Frame  305: 49 people, 49 detections, 63 tracks
# Frame  306: 48 people, 48 detections, 64 tracks
# Frame  307: 49 people, 49 detections, 65 tracks
# Frame  308: 47 people, 47 detections, 62 tracks
# Frame  309: 49 people, 49 detections, 63 tracks
# Frame  310: 45 people, 45 detections, 62 tracks
# Frame  311: 44 people, 44 detections, 63 tracks
# Frame  312: 46 people, 46 detections, 63 tracks
# Frame  313: 44 people, 44 detections, 60 tracks
# Frame  314: 47 people, 47 detections, 63 tracks
# Frame  315: 48 people, 48 detections, 61 tracks
# Frame  316: 46 people, 46 detections, 61 tracks
# Frame  317: 48 people, 48 detections, 62 tracks
# Frame  318: 47 people, 47 detections, 60 tracks
# Frame  319: 46 people, 46 detections, 61 tracks
# Frame  320: 47 people, 47 detections, 61 tracks
# Frame  321: 48 people, 48 detections, 60 tracks
# Frame  322: 48 people, 48 detections, 58 tracks
# Frame  323: 47 people, 47 detections, 60 tracks
# Frame  324: 46 people, 46 detections, 60 tracks
# Frame  325: 45 people, 45 detections, 59 tracks
# Frame  326: 47 people, 47 detections, 61 tracks
# Frame  327: 47 people, 47 detections, 62 tracks
# Frame  328: 45 people, 45 detections, 60 tracks
# Frame  329: 48 people, 48 detections, 62 tracks
# Frame  330: 48 people, 48 detections, 62 tracks
# Frame  331: 46 people, 46 detections, 63 tracks
# Frame  332: 49 people, 49 detections, 65 tracks
# Frame  333: 48 people, 48 detections, 64 tracks
# Frame  334: 50 people, 50 detections, 65 tracks
# Frame  335: 50 people, 50 detections, 64 tracks
# Frame  336: 47 people, 47 detections, 65 tracks
# Frame  337: 51 people, 51 detections, 65 tracks
# Frame  338: 50 people, 50 detections, 66 tracks
# Frame  339: 49 people, 49 detections, 66 tracks
# Frame  340: 49 people, 49 detections, 64 tracks
# Frame  341: 50 people, 50 detections, 65 tracks
# Frame  342: 50 people, 50 detections, 65 tracks
# Frame  343: 49 people, 49 detections, 65 tracks
# Frame  344: 49 people, 49 detections, 66 tracks
# Frame  345: 49 people, 49 detections, 66 tracks
# Frame  346: 49 people, 49 detections, 64 tracks
# Frame  347: 49 people, 49 detections, 66 tracks
# Frame  348: 51 people, 51 detections, 66 tracks
# Frame  349: 47 people, 47 detections, 65 tracks
# Frame  350: 49 people, 49 detections, 65 tracks
# Frame  351: 52 people, 52 detections, 67 tracks
# Frame  352: 53 people, 53 detections, 66 tracks
# Frame  353: 53 people, 53 detections, 64 tracks
# Frame  354: 52 people, 52 detections, 63 tracks
# Frame  355: 51 people, 51 detections, 64 tracks
# Frame  356: 50 people, 50 detections, 63 tracks
# Frame  357: 52 people, 52 detections, 65 tracks
# Frame  358: 51 people, 51 detections, 63 tracks
# Frame  359: 52 people, 52 detections, 62 tracks
# Frame  360: 54 people, 54 detections, 63 tracks
# Frame  361: 53 people, 53 detections, 62 tracks
# Frame  362: 50 people, 50 detections, 61 tracks
# Frame  363: 50 people, 50 detections, 61 tracks
# Frame  364: 50 people, 50 detections, 61 tracks
# Frame  365: 49 people, 49 detections, 61 tracks
# Frame  366: 52 people, 52 detections, 60 tracks
# Frame  367: 51 people, 51 detections, 60 tracks
# Frame  368: 51 people, 51 detections, 59 tracks
# Frame  369: 51 people, 51 detections, 60 tracks
# Frame  370: 51 people, 51 detections, 59 tracks
# Frame  371: 50 people, 50 detections, 58 tracks
# Frame  372: 51 people, 51 detections, 58 tracks
# Frame  373: 51 people, 51 detections, 58 tracks
# Frame  374: 50 people, 50 detections, 57 tracks
# Frame  375: 51 people, 51 detections, 59 tracks
# Frame  376: 49 people, 49 detections, 57 tracks
# Frame  377: 48 people, 48 detections, 58 tracks
# Frame  378: 47 people, 47 detections, 57 tracks
# Frame  379: 48 people, 48 detections, 57 tracks
# Frame  380: 52 people, 52 detections, 58 tracks
# Frame  381: 49 people, 49 detections, 57 tracks
# Frame  382: 50 people, 50 detections, 59 tracks
# Frame  383: 49 people, 49 detections, 58 tracks
# Frame  384: 49 people, 49 detections, 58 tracks
# Frame  385: 47 people, 47 detections, 56 tracks
# Frame  386: 47 people, 47 detections, 58 tracks
# Frame  387: 52 people, 52 detections, 60 tracks
# Frame  388: 48 people, 48 detections, 57 tracks
# Frame  389: 49 people, 49 detections, 59 tracks
# Frame  390: 50 people, 50 detections, 58 tracks
# Frame  391: 52 people, 52 detections, 60 tracks
# Frame  392: 53 people, 53 detections, 61 tracks
# Frame  393: 49 people, 49 detections, 60 tracks
# Frame  394: 48 people, 48 detections, 60 tracks
# Frame  395: 52 people, 52 detections, 61 tracks
# Frame  396: 51 people, 51 detections, 60 tracks
# Frame  397: 51 people, 51 detections, 60 tracks
# Frame  398: 51 people, 51 detections, 61 tracks
# Frame  399: 48 people, 48 detections, 61 tracks
# Frame  400: 49 people, 49 detections, 61 tracks
# Frame  401: 49 people, 49 detections, 60 tracks
# Frame  402: 47 people, 47 detections, 61 tracks
# Frame  403: 45 people, 45 detections, 60 tracks
# Frame  404: 51 people, 51 detections, 62 tracks
# Frame  405: 49 people, 49 detections, 63 tracks
# Frame  406: 48 people, 48 detections, 62 tracks
# Frame  407: 48 people, 48 detections, 61 tracks
# Frame  408: 48 people, 48 detections, 62 tracks
# Frame  409: 49 people, 49 detections, 62 tracks
# Frame  410: 47 people, 47 detections, 62 tracks
# Frame  411: 49 people, 49 detections, 62 tracks
# Frame  412: 52 people, 52 detections, 65 tracks
# Frame  413: 46 people, 46 detections, 62 tracks
# Frame  414: 46 people, 46 detections, 62 tracks
# Frame  415: 47 people, 47 detections, 62 tracks
# Frame  416: 50 people, 50 detections, 63 tracks
# Frame  417: 51 people, 51 detections, 64 tracks
# Frame  418: 52 people, 52 detections, 64 tracks
# Frame  419: 51 people, 51 detections, 64 tracks
# Frame  420: 54 people, 54 detections, 66 tracks
# Frame  421: 54 people, 54 detections, 67 tracks
# Frame  422: 51 people, 51 detections, 65 tracks
# Frame  423: 55 people, 55 detections, 66 tracks
# Frame  424: 53 people, 53 detections, 66 tracks
# Frame  425: 52 people, 52 detections, 64 tracks
# Frame  426: 51 people, 51 detections, 64 tracks
# Frame  427: 51 people, 51 detections, 64 tracks
# Frame  428: 51 people, 51 detections, 65 tracks
# Frame  429: 50 people, 50 detections, 63 tracks
# Frame  430: 51 people, 51 detections, 65 tracks
# Frame  431: 50 people, 50 detections, 63 tracks
# Frame  432: 49 people, 49 detections, 62 tracks
# Frame  433: 49 people, 49 detections, 60 tracks
# Frame  434: 50 people, 50 detections, 62 tracks
# Frame  435: 50 people, 50 detections, 62 tracks
# Frame  436: 50 people, 50 detections, 61 tracks
# Frame  437: 54 people, 54 detections, 64 tracks
# Frame  438: 48 people, 48 detections, 59 tracks
# Frame  439: 50 people, 50 detections, 61 tracks
# Frame  440: 52 people, 52 detections, 61 tracks
# Frame  441: 49 people, 49 detections, 60 tracks
# Frame  442: 50 people, 50 detections, 62 tracks
# Frame  443: 47 people, 47 detections, 60 tracks
# Frame  444: 50 people, 50 detections, 62 tracks
# Frame  445: 49 people, 49 detections, 62 tracks
# Frame  446: 51 people, 51 detections, 62 tracks
# Frame  447: 50 people, 50 detections, 63 tracks
# Frame  448: 52 people, 52 detections, 64 tracks
# Frame  449: 52 people, 52 detections, 63 tracks
# Frame  450: 49 people, 49 detections, 62 tracks
# Frame  451: 51 people, 51 detections, 64 tracks
# Frame  452: 49 people, 49 detections, 63 tracks
# Frame  453: 51 people, 51 detections, 65 tracks
# Frame  454: 52 people, 52 detections, 65 tracks
# Frame  455: 51 people, 51 detections, 64 tracks
# Frame  456: 47 people, 47 detections, 63 tracks
# Frame  457: 51 people, 51 detections, 66 tracks
# Frame  458: 47 people, 47 detections, 65 tracks
# Frame  459: 51 people, 51 detections, 66 tracks
# Frame  460: 49 people, 49 detections, 67 tracks
# Frame  461: 45 people, 45 detections, 66 tracks
# Frame  462: 47 people, 47 detections, 66 tracks
# Frame  463: 48 people, 48 detections, 67 tracks
# Frame  464: 46 people, 46 detections, 67 tracks
# Frame  465: 50 people, 50 detections, 69 tracks
# Frame  466: 49 people, 49 detections, 67 tracks
# Frame  467: 47 people, 47 detections, 68 tracks
# Frame  468: 48 people, 48 detections, 69 tracks
# Frame  469: 50 people, 50 detections, 72 tracks
# Frame  470: 45 people, 45 detections, 70 tracks
# Frame  471: 46 people, 46 detections, 70 tracks
# Frame  472: 47 people, 47 detections, 71 tracks
# Frame  473: 49 people, 49 detections, 70 tracks
# Frame  474: 46 people, 46 detections, 71 tracks
# Frame  475: 47 people, 47 detections, 71 tracks
# Frame  476: 46 people, 46 detections, 70 tracks
# Frame  477: 48 people, 48 detections, 69 tracks
# Frame  478: 46 people, 46 detections, 68 tracks
# Frame  479: 51 people, 51 detections, 69 tracks
# Frame  480: 48 people, 48 detections, 69 tracks
# Frame  481: 46 people, 46 detections, 69 tracks
# Frame  482: 44 people, 44 detections, 69 tracks
# Frame  483: 48 people, 48 detections, 70 tracks
# Frame  484: 47 people, 47 detections, 70 tracks
# Frame  485: 48 people, 48 detections, 70 tracks
# Frame  486: 47 people, 47 detections, 68 tracks
# Frame  487: 46 people, 46 detections, 68 tracks
# Frame  488: 46 people, 46 detections, 67 tracks
# Frame  489: 46 people, 46 detections, 68 tracks
# Frame  490: 47 people, 47 detections, 67 tracks
# Frame  491: 50 people, 50 detections, 66 tracks
# Frame  492: 49 people, 49 detections, 66 tracks
# Frame  493: 52 people, 52 detections, 67 tracks
# Frame  494: 48 people, 48 detections, 68 tracks
# Frame  495: 46 people, 46 detections, 66 tracks
# Frame  496: 48 people, 48 detections, 67 tracks
# Frame  497: 46 people, 46 detections, 66 tracks
# Frame  498: 46 people, 46 detections, 66 tracks
# Frame  499: 48 people, 48 detections, 66 tracks
# Frame  500: 47 people, 47 detections, 66 tracks
# Frame  501: 46 people, 46 detections, 66 tracks
# Frame  502: 47 people, 47 detections, 66 tracks
# Frame  503: 46 people, 46 detections, 66 tracks
# Frame  504: 47 people, 47 detections, 67 tracks
# Frame  505: 47 people, 47 detections, 66 tracks
# Frame  506: 48 people, 48 detections, 65 tracks
# Frame  507: 48 people, 48 detections, 65 tracks
# Frame  508: 47 people, 47 detections, 65 tracks
# Frame  509: 49 people, 49 detections, 65 tracks
# Frame  510: 47 people, 47 detections, 64 tracks
# Frame  511: 47 people, 47 detections, 64 tracks
# Frame  512: 46 people, 46 detections, 63 tracks
# Frame  513: 47 people, 47 detections, 65 tracks
# Frame  514: 46 people, 46 detections, 62 tracks
# Frame  515: 44 people, 44 detections, 62 tracks
# Frame  516: 45 people, 45 detections, 62 tracks
# Frame  517: 47 people, 47 detections, 64 tracks
# Frame  518: 46 people, 46 detections, 61 tracks
# Frame  519: 47 people, 47 detections, 64 tracks
# Frame  520: 41 people, 41 detections, 62 tracks
# Frame  521: 46 people, 46 detections, 63 tracks
# Frame  522: 45 people, 45 detections, 62 tracks
# Frame  523: 45 people, 45 detections, 61 tracks
# Frame  524: 46 people, 46 detections, 58 tracks
# Frame  525: 45 people, 45 detections, 58 tracks
# Frame  526: 49 people, 49 detections, 58 tracks
# Frame  527: 48 people, 48 detections, 60 tracks
# Frame  528: 47 people, 47 detections, 60 tracks
# Frame  529: 49 people, 49 detections, 58 tracks
# Frame  530: 49 people, 49 detections, 57 tracks
# Frame  531: 49 people, 49 detections, 61 tracks
# Frame  532: 48 people, 48 detections, 60 tracks
# Frame  533: 50 people, 50 detections, 60 tracks
# Frame  534: 45 people, 45 detections, 59 tracks
# Frame  535: 51 people, 51 detections, 62 tracks
# Frame  536: 48 people, 48 detections, 60 tracks
# Frame  537: 43 people, 43 detections, 60 tracks
# Frame  538: 44 people, 44 detections, 61 tracks
# Frame  539: 46 people, 46 detections, 60 tracks
# Frame  540: 49 people, 49 detections, 63 tracks
# Frame  541: 48 people, 48 detections, 61 tracks
# Frame  542: 41 people, 41 detections, 60 tracks
# Frame  543: 45 people, 45 detections, 61 tracks
# Frame  544: 45 people, 45 detections, 60 tracks
# Frame  545: 45 people, 45 detections, 62 tracks
# Frame  546: 46 people, 46 detections, 63 tracks
# Frame  547: 47 people, 47 detections, 64 tracks
# Frame  548: 46 people, 46 detections, 62 tracks
# Frame  549: 43 people, 43 detections, 61 tracks
# Frame  550: 45 people, 45 detections, 62 tracks
# Frame  551: 39 people, 39 detections, 60 tracks
# Frame  552: 41 people, 41 detections, 60 tracks
# Frame  553: 43 people, 43 detections, 61 tracks
# Frame  554: 42 people, 42 detections, 61 tracks
# Frame  555: 42 people, 42 detections, 61 tracks
# Frame  556: 45 people, 45 detections, 61 tracks
# Frame  557: 42 people, 42 detections, 61 tracks
# Frame  558: 39 people, 39 detections, 60 tracks
# Frame  559: 43 people, 43 detections, 60 tracks
# Frame  560: 42 people, 42 detections, 61 tracks
# Frame  561: 43 people, 43 detections, 60 tracks
# Frame  562: 42 people, 42 detections, 60 tracks
# Frame  563: 43 people, 43 detections, 62 tracks
# Frame  564: 40 people, 40 detections, 59 tracks
# Frame  565: 42 people, 42 detections, 60 tracks
# Frame  566: 42 people, 42 detections, 60 tracks
# Frame  567: 43 people, 43 detections, 61 tracks
# Frame  568: 43 people, 43 detections, 61 tracks
# Frame  569: 43 people, 43 detections, 61 tracks
# Frame  570: 44 people, 44 detections, 61 tracks
# Frame  571: 42 people, 42 detections, 61 tracks
# Frame  572: 41 people, 41 detections, 60 tracks
# Frame  573: 42 people, 42 detections, 60 tracks
# Frame  574: 43 people, 43 detections, 61 tracks
# Frame  575: 43 people, 43 detections, 58 tracks
# Frame  576: 42 people, 42 detections, 58 tracks
# Frame  577: 42 people, 42 detections, 59 tracks
# Frame  578: 44 people, 44 detections, 56 tracks
# Frame  579: 44 people, 44 detections, 56 tracks
# Frame  580: 42 people, 42 detections, 55 tracks
# Frame  581: 45 people, 45 detections, 56 tracks
# Frame  582: 46 people, 46 detections, 57 tracks
# Frame  583: 44 people, 44 detections, 55 tracks
# Frame  584: 44 people, 44 detections, 56 tracks
# Frame  585: 45 people, 45 detections, 56 tracks
# Frame  586: 45 people, 45 detections, 57 tracks
# Frame  587: 42 people, 42 detections, 56 tracks
# Frame  588: 41 people, 41 detections, 55 tracks
# Frame  589: 43 people, 43 detections, 56 tracks
# Frame  590: 42 people, 42 detections, 55 tracks
# Frame  591: 40 people, 40 detections, 55 tracks
# Frame  592: 40 people, 40 detections, 55 tracks
# Frame  593: 40 people, 40 detections, 56 tracks
# Frame  594: 41 people, 41 detections, 57 tracks
# Frame  595: 40 people, 40 detections, 56 tracks
# Frame  596: 41 people, 41 detections, 57 tracks
# Frame  597: 41 people, 41 detections, 58 tracks
# Frame  598: 42 people, 42 detections, 58 tracks
# Frame  599: 42 people, 42 detections, 59 tracks
# Frame  600: 40 people, 40 detections, 58 tracks
# Frame  601: 38 people, 38 detections, 57 tracks
# Frame  602: 38 people, 38 detections, 57 tracks
# Frame  603: 41 people, 41 detections, 59 tracks
# Frame  604: 41 people, 41 detections, 58 tracks
# Frame  605: 41 people, 41 detections, 58 tracks
# Frame  606: 41 people, 41 detections, 57 tracks
# Frame  607: 45 people, 45 detections, 58 tracks
# Frame  608: 44 people, 44 detections, 58 tracks
# Frame  609: 45 people, 45 detections, 58 tracks
# Frame  610: 43 people, 43 detections, 56 tracks
# Frame  611: 44 people, 44 detections, 57 tracks
# Frame  612: 48 people, 48 detections, 58 tracks
# Frame  613: 43 people, 43 detections, 54 tracks
# Frame  614: 40 people, 40 detections, 54 tracks
# Frame  615: 41 people, 41 detections, 54 tracks
# Frame  616: 41 people, 41 detections, 55 tracks
# Frame  617: 41 people, 41 detections, 55 tracks
# Frame  618: 44 people, 44 detections, 57 tracks
# Frame  619: 47 people, 47 detections, 58 tracks
# Frame  620: 47 people, 47 detections, 57 tracks
# Frame  621: 46 people, 46 detections, 55 tracks
# Frame  622: 48 people, 48 detections, 58 tracks
# Frame  623: 43 people, 43 detections, 57 tracks
# Frame  624: 47 people, 47 detections, 59 tracks
# Frame  625: 47 people, 47 detections, 59 tracks
# Frame  626: 47 people, 47 detections, 58 tracks
# Frame  627: 41 people, 41 detections, 58 tracks
# Frame  628: 43 people, 43 detections, 58 tracks
# Frame  629: 42 people, 42 detections, 58 tracks
# Frame  630: 45 people, 45 detections, 58 tracks
# Frame  631: 44 people, 44 detections, 57 tracks
# Frame  632: 45 people, 45 detections, 58 tracks
# Frame  633: 43 people, 43 detections, 57 tracks
# Frame  634: 42 people, 42 detections, 58 tracks
# Frame  635: 45 people, 45 detections, 58 tracks
# Frame  636: 46 people, 46 detections, 60 tracks
# Frame  637: 42 people, 42 detections, 58 tracks
# Frame  638: 46 people, 46 detections, 60 tracks
# Frame  639: 49 people, 49 detections, 62 tracks
# Frame  640: 46 people, 46 detections, 62 tracks
# Frame  641: 42 people, 42 detections, 60 tracks
# Frame  642: 44 people, 44 detections, 61 tracks
# Frame  643: 47 people, 47 detections, 61 tracks
# Frame  644: 45 people, 45 detections, 59 tracks
# Frame  645: 46 people, 46 detections, 59 tracks
# Frame  646: 47 people, 47 detections, 59 tracks
# Frame  647: 45 people, 45 detections, 59 tracks
# Frame  648: 44 people, 44 detections, 59 tracks
# Frame  649: 45 people, 45 detections, 61 tracks
# Frame  650: 41 people, 41 detections, 59 tracks
# Frame  651: 37 people, 37 detections, 59 tracks
# Frame  652: 41 people, 41 detections, 61 tracks
# Frame  653: 38 people, 38 detections, 60 tracks
# Frame  654: 40 people, 40 detections, 60 tracks
# Frame  655: 41 people, 41 detections, 60 tracks
# Frame  656: 44 people, 44 detections, 61 tracks
# Frame  657: 44 people, 44 detections, 59 tracks
# Frame  658: 42 people, 42 detections, 59 tracks
# Frame  659: 42 people, 42 detections, 59 tracks
# Frame  660: 38 people, 38 detections, 59 tracks
# Frame  661: 44 people, 44 detections, 60 tracks
# Frame  662: 40 people, 40 detections, 59 tracks
# Frame  663: 42 people, 42 detections, 59 tracks
# Frame  664: 42 people, 42 detections, 59 tracks
# Frame  665: 40 people, 40 detections, 58 tracks
# Frame  666: 42 people, 42 detections, 59 tracks
# Frame  667: 42 people, 42 detections, 57 tracks
# Frame  668: 43 people, 43 detections, 59 tracks
# Frame  669: 42 people, 42 detections, 58 tracks
# Frame  670: 39 people, 39 detections, 58 tracks
# Frame  671: 40 people, 40 detections, 59 tracks
# Frame  672: 42 people, 42 detections, 60 tracks
# Frame  673: 40 people, 40 detections, 59 tracks
# Frame  674: 38 people, 38 detections, 59 tracks
# Frame  675: 42 people, 42 detections, 61 tracks
# Frame  676: 43 people, 43 detections, 60 tracks
# Frame  677: 40 people, 40 detections, 60 tracks
# Frame  678: 39 people, 39 detections, 59 tracks
# Frame  679: 40 people, 40 detections, 57 tracks
# Frame  680: 43 people, 43 detections, 59 tracks
# Frame  681: 41 people, 41 detections, 59 tracks
# Frame  682: 45 people, 45 detections, 61 tracks
# Frame  683: 47 people, 47 detections, 59 tracks
# Frame  684: 42 people, 42 detections, 58 tracks
# Frame  685: 47 people, 47 detections, 59 tracks
# Frame  686: 44 people, 44 detections, 56 tracks
# Frame  687: 41 people, 41 detections, 56 tracks
# Frame  688: 43 people, 43 detections, 56 tracks
# Frame  689: 42 people, 42 detections, 56 tracks
# Frame  690: 42 people, 42 detections, 57 tracks
# Frame  691: 39 people, 39 detections, 56 tracks
# Frame  692: 41 people, 41 detections, 54 tracks
# Frame  693: 41 people, 41 detections, 55 tracks
# Frame  694: 44 people, 44 detections, 57 tracks
# Frame  695: 39 people, 39 detections, 56 tracks
# Frame  696: 42 people, 42 detections, 56 tracks
# Frame  697: 43 people, 43 detections, 57 tracks
# Frame  698: 42 people, 42 detections, 57 tracks
# Frame  699: 42 people, 42 detections, 57 tracks
# Frame  700: 42 people, 42 detections, 57 tracks
# Frame  701: 41 people, 41 detections, 56 tracks
# Frame  702: 43 people, 43 detections, 57 tracks
# Frame  703: 40 people, 40 detections, 56 tracks
# Frame  704: 42 people, 42 detections, 56 tracks
# Frame  705: 42 people, 42 detections, 55 tracks
# Frame  706: 39 people, 39 detections, 55 tracks
# Frame  707: 41 people, 41 detections, 55 tracks
# Frame  708: 41 people, 41 detections, 55 tracks
# Frame  709: 41 people, 41 detections, 54 tracks
# Frame  710: 41 people, 41 detections, 55 tracks
# Frame  711: 40 people, 40 detections, 54 tracks
# Frame  712: 40 people, 40 detections, 54 tracks
# Frame  713: 40 people, 40 detections, 55 tracks
# Frame  714: 42 people, 42 detections, 55 tracks
# Frame  715: 42 people, 42 detections, 54 tracks
# Frame  716: 41 people, 41 detections, 52 tracks
# Frame  717: 41 people, 41 detections, 50 tracks
# Frame  718: 39 people, 39 detections, 50 tracks
# Frame  719: 40 people, 40 detections, 50 tracks
# Frame  720: 41 people, 41 detections, 50 tracks
# Frame  721: 43 people, 43 detections, 52 tracks
# Frame  722: 43 people, 43 detections, 52 tracks
# Frame  723: 43 people, 43 detections, 51 tracks
# Frame  724: 42 people, 42 detections, 50 tracks
# Frame  725: 43 people, 43 detections, 51 tracks
# Frame  726: 43 people, 43 detections, 50 tracks
# Frame  727: 42 people, 42 detections, 48 tracks
# Frame  728: 42 people, 42 detections, 49 tracks
# Frame  729: 41 people, 41 detections, 48 tracks
# Frame  730: 45 people, 45 detections, 52 tracks
# Frame  731: 41 people, 41 detections, 49 tracks
# Frame  732: 44 people, 44 detections, 50 tracks
# Frame  733: 44 people, 44 detections, 51 tracks
# Frame  734: 43 people, 43 detections, 50 tracks
# Frame  735: 42 people, 42 detections, 51 tracks
# Frame  736: 44 people, 44 detections, 51 tracks
# Frame  737: 42 people, 42 detections, 51 tracks
# Frame  738: 42 people, 42 detections, 51 tracks
# Frame  739: 44 people, 44 detections, 53 tracks
# Frame  740: 38 people, 38 detections, 51 tracks
# Frame  741: 37 people, 37 detections, 52 tracks
# Frame  742: 41 people, 41 detections, 53 tracks
# Frame  743: 42 people, 42 detections, 52 tracks
# Frame  744: 41 people, 41 detections, 53 tracks
# Frame  745: 43 people, 43 detections, 54 tracks
# Frame  746: 41 people, 41 detections, 53 tracks
# Frame  747: 38 people, 38 detections, 54 tracks
# Frame  748: 37 people, 37 detections, 54 tracks
# Frame  749: 36 people, 36 detections, 54 tracks
# Frame  750: 40 people, 40 detections, 54 tracks
# Frame  751: 38 people, 38 detections, 54 tracks
# Frame  752: 40 people, 40 detections, 55 tracks
# Frame  753: 40 people, 40 detections, 55 tracks
# Frame  754: 41 people, 41 detections, 54 tracks
# Frame  755: 40 people, 40 detections, 56 tracks
# Frame  756: 42 people, 42 detections, 57 tracks
# Frame  757: 41 people, 41 detections, 57 tracks
# Frame  758: 40 people, 40 detections, 55 tracks
# Frame  759: 40 people, 40 detections, 55 tracks
# Frame  760: 40 people, 40 detections, 55 tracks
# Frame  761: 39 people, 39 detections, 57 tracks
# Frame  762: 39 people, 39 detections, 57 tracks
# Frame  763: 43 people, 43 detections, 57 tracks
# Frame  764: 43 people, 43 detections, 56 tracks
# Frame  765: 44 people, 44 detections, 56 tracks
# Frame  766: 42 people, 42 detections, 55 tracks
# Frame  767: 43 people, 43 detections, 55 tracks
# Frame  768: 39 people, 39 detections, 54 tracks
# Frame  769: 42 people, 42 detections, 55 tracks
# Frame  770: 43 people, 43 detections, 56 tracks
# Frame  771: 42 people, 42 detections, 53 tracks
# Frame  772: 45 people, 45 detections, 57 tracks
# Frame  773: 46 people, 46 detections, 57 tracks
# Frame  774: 45 people, 45 detections, 56 tracks
# Frame  775: 45 people, 45 detections, 56 tracks
# Frame  776: 42 people, 42 detections, 55 tracks
# Frame  777: 45 people, 45 detections, 57 tracks
# Frame  778: 42 people, 42 detections, 54 tracks
# Frame  779: 42 people, 42 detections, 55 tracks
# Frame  780: 40 people, 40 detections, 55 tracks
# Frame  781: 44 people, 44 detections, 56 tracks
# Frame  782: 42 people, 42 detections, 56 tracks
# Frame  783: 44 people, 44 detections, 55 tracks
# Frame  784: 45 people, 45 detections, 57 tracks
# Frame  785: 45 people, 45 detections, 56 tracks
# Frame  786: 43 people, 43 detections, 56 tracks
# Frame  787: 46 people, 46 detections, 57 tracks
# Frame  788: 48 people, 48 detections, 56 tracks
# Frame  789: 46 people, 46 detections, 56 tracks
# Frame  790: 47 people, 47 detections, 57 tracks
# Frame  791: 46 people, 46 detections, 57 tracks
# Frame  792: 48 people, 48 detections, 58 tracks
# Frame  793: 50 people, 50 detections, 62 tracks
# Frame  794: 47 people, 47 detections, 60 tracks
# Frame  795: 45 people, 45 detections, 59 tracks
# Frame  796: 42 people, 42 detections, 56 tracks
# Frame  797: 48 people, 48 detections, 57 tracks
# Frame  798: 46 people, 46 detections, 55 tracks
# Frame  799: 46 people, 46 detections, 57 tracks
# Frame  800: 45 people, 45 detections, 57 tracks
# Frame  801: 44 people, 44 detections, 57 tracks
# Frame  802: 43 people, 43 detections, 58 tracks
# Frame  803: 44 people, 44 detections, 61 tracks
# Frame  804: 45 people, 45 detections, 59 tracks
# Frame  805: 41 people, 41 detections, 59 tracks
# Frame  806: 43 people, 43 detections, 59 tracks
# Frame  807: 42 people, 42 detections, 58 tracks
# Frame  808: 42 people, 42 detections, 58 tracks
# Frame  809: 42 people, 42 detections, 60 tracks
# Frame  810: 45 people, 45 detections, 62 tracks
# Frame  811: 43 people, 43 detections, 61 tracks
# Frame  812: 47 people, 47 detections, 63 tracks
# Frame  813: 46 people, 46 detections, 64 tracks
# Frame  814: 44 people, 44 detections, 61 tracks
# Frame  815: 42 people, 42 detections, 62 tracks
# Frame  816: 41 people, 41 detections, 61 tracks
# Frame  817: 41 people, 41 detections, 59 tracks
# Frame  818: 41 people, 41 detections, 59 tracks
# Frame  819: 43 people, 43 detections, 61 tracks
# Frame  820: 43 people, 43 detections, 62 tracks
# Frame  821: 43 people, 43 detections, 60 tracks
# Frame  822: 43 people, 43 detections, 61 tracks
# Frame  823: 40 people, 40 detections, 59 tracks
# Frame  824: 42 people, 42 detections, 60 tracks
# Frame  825: 43 people, 43 detections, 61 tracks
# Frame  826: 47 people, 47 detections, 62 tracks
# Frame  827: 46 people, 46 detections, 63 tracks
# Frame  828: 44 people, 44 detections, 60 tracks
# Frame  829: 44 people, 44 detections, 61 tracks
# Frame  830: 46 people, 46 detections, 64 tracks
# Frame  831: 46 people, 46 detections, 64 tracks
# Frame  832: 45 people, 45 detections, 61 tracks
# Frame  833: 48 people, 48 detections, 63 tracks
# Frame  834: 46 people, 46 detections, 61 tracks
# Frame  835: 47 people, 47 detections, 59 tracks
# Frame  836: 47 people, 47 detections, 61 tracks
# Frame  837: 44 people, 44 detections, 58 tracks
# Frame  838: 44 people, 44 detections, 58 tracks
# Frame  839: 43 people, 43 detections, 57 tracks
# Frame  840: 45 people, 45 detections, 58 tracks
# Frame  841: 44 people, 44 detections, 56 tracks
# Frame  842: 43 people, 43 detections, 57 tracks
# Frame  843: 42 people, 42 detections, 56 tracks
# Frame  844: 44 people, 44 detections, 57 tracks
# Frame  845: 46 people, 46 detections, 58 tracks
# Frame  846: 45 people, 45 detections, 59 tracks
# Frame  847: 43 people, 43 detections, 57 tracks
# Frame  848: 43 people, 43 detections, 57 tracks
# Frame  849: 43 people, 43 detections, 57 tracks
# Frame  850: 44 people, 44 detections, 58 tracks
# Frame  851: 47 people, 47 detections, 59 tracks
# Frame  852: 47 people, 47 detections, 60 tracks
# Frame  853: 46 people, 46 detections, 59 tracks
# Frame  854: 47 people, 47 detections, 61 tracks
# Frame  855: 46 people, 46 detections, 60 tracks
# Frame  856: 44 people, 44 detections, 61 tracks
# Frame  857: 43 people, 43 detections, 59 tracks
# Frame  858: 47 people, 47 detections, 61 tracks
# Frame  859: 45 people, 45 detections, 60 tracks
# Frame  860: 47 people, 47 detections, 60 tracks
# Frame  861: 44 people, 44 detections, 58 tracks
# Frame  862: 45 people, 45 detections, 58 tracks
# Frame  863: 44 people, 44 detections, 58 tracks
# Frame  864: 43 people, 43 detections, 59 tracks
# Frame  865: 46 people, 46 detections, 59 tracks
# Frame  866: 43 people, 43 detections, 58 tracks
# Frame  867: 41 people, 41 detections, 57 tracks
# Frame  868: 44 people, 44 detections, 57 tracks
# Frame  869: 43 people, 43 detections, 56 tracks
# Frame  870: 44 people, 44 detections, 57 tracks
# Frame  871: 43 people, 43 detections, 56 tracks
# Frame  872: 44 people, 44 detections, 56 tracks
# Frame  873: 48 people, 48 detections, 60 tracks
# Frame  874: 47 people, 47 detections, 58 tracks
# Frame  875: 47 people, 47 detections, 58 tracks
# Frame  876: 48 people, 48 detections, 60 tracks
# Frame  877: 48 people, 48 detections, 58 tracks
# Frame  878: 46 people, 46 detections, 57 tracks
# Frame  879: 46 people, 46 detections, 57 tracks
# Frame  880: 46 people, 46 detections, 57 tracks
# Frame  881: 45 people, 45 detections, 56 tracks
# Frame  882: 47 people, 47 detections, 57 tracks
# Frame  883: 47 people, 47 detections, 58 tracks
# Frame  884: 46 people, 46 detections, 58 tracks
# Frame  885: 48 people, 48 detections, 57 tracks
# Frame  886: 47 people, 47 detections, 56 tracks
# Frame  887: 48 people, 48 detections, 55 tracks
# Frame  888: 49 people, 49 detections, 55 tracks
# Frame  889: 49 people, 49 detections, 56 tracks
# Frame  890: 51 people, 51 detections, 56 tracks
# Frame  891: 47 people, 47 detections, 56 tracks
# Frame  892: 49 people, 49 detections, 56 tracks
# Frame  893: 48 people, 48 detections, 58 tracks
# Frame  894: 51 people, 51 detections, 58 tracks
# Frame  895: 50 people, 50 detections, 56 tracks
# Frame  896: 52 people, 52 detections, 57 tracks
# Frame  897: 53 people, 53 detections, 58 tracks
# Frame  898: 50 people, 50 detections, 57 tracks
# Frame  899: 53 people, 53 detections, 58 tracks
# Frame  900: 50 people, 50 detections, 59 tracks
# Frame  901: 49 people, 49 detections, 58 tracks
# Frame  902: 48 people, 48 detections, 58 tracks
# Frame  903: 50 people, 50 detections, 59 tracks
# Frame  904: 51 people, 51 detections, 59 tracks
# Frame  905: 47 people, 47 detections, 58 tracks
# Frame  906: 48 people, 48 detections, 59 tracks
# Frame  907: 50 people, 50 detections, 58 tracks
# Frame  908: 50 people, 50 detections, 59 tracks
# Frame  909: 47 people, 47 detections, 58 tracks
# Frame  910: 51 people, 51 detections, 58 tracks
# Frame  911: 52 people, 52 detections, 59 tracks
# Frame  912: 51 people, 51 detections, 60 tracks
# Frame  913: 49 people, 49 detections, 59 tracks
# Frame  914: 49 people, 49 detections, 58 tracks
# Frame  915: 49 people, 49 detections, 60 tracks
# Frame  916: 50 people, 50 detections, 61 tracks
# Frame  917: 48 people, 48 detections, 58 tracks
# Frame  918: 48 people, 48 detections, 60 tracks
# Frame  919: 45 people, 45 detections, 58 tracks
# Frame  920: 50 people, 50 detections, 59 tracks
# Frame  921: 53 people, 53 detections, 60 tracks
# Frame  922: 51 people, 51 detections, 60 tracks
# Frame  923: 53 people, 53 detections, 60 tracks
# Frame  924: 53 people, 53 detections, 61 tracks
# Frame  925: 52 people, 52 detections, 59 tracks
# Frame  926: 53 people, 53 detections, 60 tracks
# Frame  927: 52 people, 52 detections, 61 tracks
# Frame  928: 53 people, 53 detections, 60 tracks
# Frame  929: 51 people, 51 detections, 61 tracks
# Frame  930: 52 people, 52 detections, 60 tracks
# Frame  931: 49 people, 49 detections, 60 tracks
# Frame  932: 49 people, 49 detections, 60 tracks
# Frame  933: 48 people, 48 detections, 60 tracks
# Frame  934: 48 people, 48 detections, 60 tracks
# Frame  935: 49 people, 49 detections, 60 tracks
# Frame  936: 47 people, 47 detections, 59 tracks
# Frame  937: 48 people, 48 detections, 59 tracks
# Frame  938: 50 people, 50 detections, 59 tracks
# Frame  939: 48 people, 48 detections, 59 tracks
# Frame  940: 48 people, 48 detections, 59 tracks
# Frame  941: 49 people, 49 detections, 60 tracks
# Frame  942: 49 people, 49 detections, 60 tracks
# Frame  943: 50 people, 50 detections, 60 tracks
# Frame  944: 48 people, 48 detections, 59 tracks
# Frame  945: 50 people, 50 detections, 59 tracks
# Frame  946: 50 people, 50 detections, 60 tracks
# Frame  947: 51 people, 51 detections, 62 tracks
# Frame  948: 51 people, 51 detections, 62 tracks
# Frame  949: 49 people, 49 detections, 60 tracks
# Frame  950: 49 people, 49 detections, 60 tracks
# Frame  951: 49 people, 49 detections, 61 tracks
# Frame  952: 49 people, 49 detections, 60 tracks
# Frame  953: 50 people, 50 detections, 60 tracks
# Frame  954: 49 people, 49 detections, 60 tracks
# Frame  955: 52 people, 52 detections, 61 tracks
# Frame  956: 48 people, 48 detections, 62 tracks
# Frame  957: 54 people, 54 detections, 64 tracks
# Frame  958: 53 people, 53 detections, 63 tracks
# Frame  959: 48 people, 48 detections, 63 tracks
# Frame  960: 51 people, 51 detections, 63 tracks
# Frame  961: 53 people, 53 detections, 63 tracks
# Frame  962: 54 people, 54 detections, 64 tracks
# Frame  963: 50 people, 50 detections, 62 tracks
# Frame  964: 52 people, 52 detections, 65 tracks
# Frame  965: 55 people, 55 detections, 66 tracks
# Frame  966: 52 people, 52 detections, 62 tracks
# Frame  967: 54 people, 54 detections, 63 tracks
# Frame  968: 53 people, 53 detections, 63 tracks
# Frame  969: 56 people, 56 detections, 63 tracks
# Frame  970: 57 people, 57 detections, 65 tracks
# Frame  971: 54 people, 54 detections, 64 tracks
# Frame  972: 53 people, 53 detections, 63 tracks
# Frame  973: 52 people, 52 detections, 64 tracks
# Frame  974: 49 people, 49 detections, 65 tracks
# Frame  975: 49 people, 49 detections, 65 tracks
# Frame  976: 52 people, 52 detections, 66 tracks
# Frame  977: 49 people, 49 detections, 66 tracks
# Frame  978: 50 people, 50 detections, 66 tracks
# Frame  979: 50 people, 50 detections, 64 tracks
# Frame  980: 50 people, 50 detections, 65 tracks
# Frame  981: 49 people, 49 detections, 64 tracks
# Frame  982: 54 people, 54 detections, 68 tracks
# Frame  983: 51 people, 51 detections, 68 tracks
# Frame  984: 48 people, 48 detections, 66 tracks
# Frame  985: 53 people, 53 detections, 68 tracks
# Frame  986: 54 people, 54 detections, 69 tracks
# Frame  987: 54 people, 54 detections, 69 tracks
# Frame  988: 51 people, 51 detections, 69 tracks
# Frame  989: 51 people, 51 detections, 70 tracks
# Frame  990: 49 people, 49 detections, 69 tracks
# Frame  991: 50 people, 50 detections, 71 tracks
# Frame  992: 55 people, 55 detections, 71 tracks
# Frame  993: 56 people, 56 detections, 72 tracks
# Frame  994: 55 people, 55 detections, 72 tracks
# Frame  995: 55 people, 55 detections, 71 tracks
# Frame  996: 59 people, 59 detections, 73 tracks
# Frame  997: 57 people, 57 detections, 73 tracks
# Frame  998: 54 people, 54 detections, 71 tracks
# Frame  999: 58 people, 58 detections, 75 tracks
# Frame 1000: 56 people, 56 detections, 72 tracks
# Frame 1001: 53 people, 53 detections, 71 tracks
# Frame 1002: 55 people, 55 detections, 71 tracks
# Frame 1003: 53 people, 53 detections, 72 tracks
# Frame 1004: 55 people, 55 detections, 71 tracks
# Frame 1005: 55 people, 55 detections, 72 tracks
# Frame 1006: 54 people, 54 detections, 70 tracks
# Frame 1007: 53 people, 53 detections, 70 tracks
# Frame 1008: 54 people, 54 detections, 69 tracks
# Frame 1009: 55 people, 55 detections, 69 tracks
# Frame 1010: 53 people, 53 detections, 69 tracks
# Frame 1011: 58 people, 58 detections, 72 tracks
# Frame 1012: 58 people, 58 detections, 73 tracks
# Frame 1013: 53 people, 53 detections, 70 tracks
# Frame 1014: 54 people, 54 detections, 71 tracks
# Frame 1015: 55 people, 55 detections, 74 tracks
# Frame 1016: 52 people, 52 detections, 71 tracks
# Frame 1017: 53 people, 53 detections, 70 tracks
# Frame 1018: 57 people, 57 detections, 72 tracks
# Frame 1019: 57 people, 57 detections, 72 tracks
# Frame 1020: 57 people, 57 detections, 71 tracks
# Frame 1021: 57 people, 57 detections, 71 tracks
# Frame 1022: 54 people, 54 detections, 70 tracks
# Frame 1023: 54 people, 54 detections, 69 tracks
# Frame 1024: 56 people, 56 detections, 69 tracks
# Frame 1025: 56 people, 56 detections, 68 tracks
# Frame 1026: 56 people, 56 detections, 68 tracks
# Frame 1027: 56 people, 56 detections, 68 tracks
# Frame 1028: 57 people, 57 detections, 69 tracks
# Frame 1029: 58 people, 58 detections, 68 tracks
# Frame 1030: 56 people, 56 detections, 68 tracks
# Frame 1031: 55 people, 55 detections, 67 tracks
# Frame 1032: 56 people, 56 detections, 71 tracks
# Frame 1033: 54 people, 54 detections, 69 tracks
# Frame 1034: 55 people, 55 detections, 69 tracks
# Frame 1035: 53 people, 53 detections, 68 tracks
# Frame 1036: 53 people, 53 detections, 70 tracks
# Frame 1037: 50 people, 50 detections, 69 tracks
# Frame 1038: 54 people, 54 detections, 72 tracks
# Frame 1039: 55 people, 55 detections, 70 tracks
# Frame 1040: 53 people, 53 detections, 70 tracks
# Frame 1041: 52 people, 52 detections, 71 tracks
# Frame 1042: 52 people, 52 detections, 70 tracks
# Frame 1043: 55 people, 55 detections, 73 tracks
# Frame 1044: 50 people, 50 detections, 71 tracks
# Frame 1045: 51 people, 51 detections, 72 tracks
# Frame 1046: 49 people, 49 detections, 72 tracks
# Frame 1047: 50 people, 50 detections, 73 tracks
# Frame 1048: 50 people, 50 detections, 72 tracks
# Frame 1049: 50 people, 50 detections, 73 tracks
# Frame 1050: 53 people, 53 detections, 71 tracks
#
# Saved input video to   task2_input.mp4
# Saved tracked video to task2.mp4
# Saved tracks to        task2_tracks.txt

# %% [markdown]
# ### 4.2 Save frame counts

# %%
# ============================================
# 4.2 Save Task2 frame counts to CSV for Kaggle
#     Format:
#       Number,Count
#       1,12
#       2,15
#       ...
# ============================================
def save_counts_to_csv(frame_counts: dict, csv_path: Path):
    """
    frame_counts: dict[frame_idx] -> count
    """
    data = []
    for frame_idx in sorted(frame_counts.keys()):
        data.append({"Number": frame_idx, "Count": frame_counts[frame_idx]})

    df = pd.DataFrame(data)
    df.to_csv(csv_path, index=False)
    print(f"Saved counts to {csv_path}")


save_counts_to_csv(task2_frame_counts, TASK2_COUNTS_CSV)
# Out:
# Saved counts to task2_count.csv

# %% [markdown]
# ## Kaggle Score Explanation
#
# Our Kaggle RMSE score was **2.38**. Errors mainly come from:
#
# - **Overcounting:** Duplicate detections on the same person in crowded frames.
# - **Undercounting:** Small or distant pedestrians are often missed.
# - **Threshold sensitivity:** The detector score threshold was not fully optimized.
#
# These factors cause the predicted counts to differ from the ground truth by ~2–3 people on average.

# %% [markdown]
# ## Final Summary
#
# We built videos, tracked pedestrians, evaluated tracking with MOTA, and generated per-frame counts for Task 2. The results depend heavily on detection quality, occlusions, and threshold choices.
